# %% [markdown]
# <a href="https://colab.research.google.com/github/SaurabhDataDock/First-repository/blob/main/EDA__Group1__Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('/content/sampled_combined_data.csv')

# Display the first few rows
print(df.head())

# Check basic info about the dataset
print(df.info())

# Check for missing values
print(df.isnull().sum())
# Out:
#      index  FlightDate                 Airline Origin Dest  Cancelled  \
# 0  2846883  2018-03-24  Hawaiian Airlines Inc.    LIH  HNL      False
# 1  3173911  2018-04-23       Endeavor Air Inc.    BOS  PIT      False
# 2  2435108  2018-02-16  Southwest Airlines Co.    HOU  ECP      False
# 3  2234995  2018-12-07  Southwest Airlines Co.    MDW  MCO      False
# 4  3986585  2018-06-03  Southwest Airlines Co.    LAS  LIT      False
#
#    Diverted  CRSDepTime  DepTime  DepDelayMinutes  ...  WheelsOn  TaxiIn  \
# 0     False        1900   1855.0              0.0  ...    1920.0     7.0
# 1     False        2055   2111.0             16.0  ...    2253.0    23.0
# 2     False        1650   1728.0             38.0  ...    1859.0     4.0
# 3     False        1845   1851.0              6.0  ...    2207.0     7.0
# 4     False        1200   1201.0              1.0  ...    1637.0     2.0
#
#    CRSArrTime  ArrDelay  ArrDel15  ArrivalDelayGroups  ArrTimeBlk  \
# 0        1935      -8.0       0.0                -1.0   1900-1959
# 1        2249      27.0       1.0                 1.0   2200-2259
# 2        1820      43.0       1.0                 2.0   1800-1859
# 3        2215      -1.0       0.0                -1.0   2200-2259
# 4        1655     -16.0       0.0                -2.0   1600-1659
#
#    DistanceGroup  DivAirportLandings  Unnamed: 0
# 0              1                 0.0         NaN
# 1              2                 0.0         NaN
# 2              3                 0.0         NaN
# 3              4                 0.0         NaN
# 4              6                 0.0         NaN
#
# [5 rows x 63 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 63 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   index                                    60000 non-null  int64
#  1   FlightDate                               60000 non-null  object
#  2   Airline                                  60000 non-null  object
#  3   Origin                                   60000 non-null  object
#  4   Dest                                     60000 non-null  object
#  5   Cancelled                                60000 non-null  bool
#  6   Diverted                                 60000 non-null  bool
#  7   CRSDepTime                               60000 non-null  int64
#  8   DepTime                                  58272 non-null  float64
#  9   DepDelayMinutes                          58269 non-null  float64
#  10  DepDelay                                 58269 non-null  float64
#  11  ArrTime                                  58226 non-null  float64
#  12  ArrDelayMinutes                          58111 non-null  float64
#  13  AirTime                                  58100 non-null  float64
#  14  CRSElapsedTime                           60000 non-null  float64
#  15  ActualElapsedTime                        58111 non-null  float64
#  16  Distance                                 60000 non-null  float64
#  17  Year                                     60000 non-null  int64
#  18  Quarter                                  60000 non-null  int64
#  19  Month                                    60000 non-null  int64
#  20  DayofMonth                               60000 non-null  int64
#  21  DayOfWeek                                60000 non-null  int64
#  22  Marketing_Airline_Network                60000 non-null  object
#  23  Operated_or_Branded_Code_Share_Partners  60000 non-null  object
#  24  DOT_ID_Marketing_Airline                 60000 non-null  int64
#  25  IATA_Code_Marketing_Airline              60000 non-null  object
#  26  Flight_Number_Marketing_Airline          60000 non-null  int64
#  27  Operating_Airline                        60000 non-null  object
#  28  DOT_ID_Operating_Airline                 60000 non-null  int64
#  29  IATA_Code_Operating_Airline              60000 non-null  object
#  30  Tail_Number                              59390 non-null  object
#  31  Flight_Number_Operating_Airline          60000 non-null  int64
#  32  OriginAirportID                          60000 non-null  int64
#  33  OriginAirportSeqID                       60000 non-null  int64
#  34  OriginCityMarketID                       60000 non-null  int64
#  35  OriginCityName                           60000 non-null  object
#  36  OriginState                              60000 non-null  object
#  37  OriginStateFips                          60000 non-null  int64
#  38  OriginStateName                          60000 non-null  object
#  39  OriginWac                                60000 non-null  int64
#  40  DestAirportID                            60000 non-null  int64
#  41  DestAirportSeqID                         60000 non-null  int64
#  42  DestCityMarketID                         60000 non-null  int64
#  43  DestCityName                             60000 non-null  object
#  44  DestState                                60000 non-null  object
#  45  DestStateFips                            60000 non-null  int64
#  46  DestStateName                            60000 non-null  object
#  47  DestWac                                  60000 non-null  int64
#  48  DepDel15                                 58269 non-null  float64
#  49  DepartureDelayGroups                     58269 non-null  float64
#  50  DepTimeBlk                               60000 non-null  object
#  51  TaxiOut                                  58232 non-null  float64
#  52  WheelsOff                                58232 non-null  float64
#  53  WheelsOn                                 58215 non-null  float64
#  54  TaxiIn                                   58215 non-null  float64
#  55  CRSArrTime                               60000 non-null  int64
#  56  ArrDelay                                 58111 non-null  float64
#  57  ArrDel15                                 58111 non-null  float64
#  58  ArrivalDelayGroups                       58111 non-null  float64
#  59  ArrTimeBlk                               60000 non-null  object
#  60  DistanceGroup                            60000 non-null  int64
#  61  DivAirportLandings                       60000 non-null  float64
#  62  Unnamed: 0                               50000 non-null  float64
# dtypes: bool(2), float64(20), int64(23), object(18)
# memory usage: 28.0+ MB
# None
# index                     0
# FlightDate                0
# Airline                   0
# Origin                    0
# Dest                      0
#                       ...
# ArrivalDelayGroups     1889
# ArrTimeBlk                0
# DistanceGroup             0
# DivAirportLandings        0
# Unnamed: 0            10000
# Length: 63, dtype: int64

# %%
# HANDLING MISSING VALUES

# Drop rows with missing values (if appropriate)

# Drop rows with missing values (if appropriate)
df = df.dropna()

df.drop_duplicates(keep='first',inplace=True)

# %%
# FEATURE ENGINEERING

# %%
import pandas as pd

# Convert 'FlightDate' to datetime
df['FlightDate'] = pd.to_datetime(df['FlightDate'])

# Check the result
print(df['FlightDate'].head())
# Out:
# 10000   2019-12-25
# 10001   2019-12-30
# 10002   2019-04-10
# 10003   2019-04-10
# 10004   2019-10-18
# Name: FlightDate, dtype: datetime64[ns]

# %%
# Extract month (1 for January, 2 for February, etc.)
df['Month'] = df['FlightDate'].dt.month

# Check the result
print(df[['FlightDate', 'Month']].head())
# Out:
#       FlightDate  Month
# 10000 2019-12-25     12
# 10001 2019-12-30     12
# 10002 2019-04-10      4
# 10003 2019-04-10      4
# 10004 2019-10-18     10

# %%
# Extract week of the year
df['Week'] = df['FlightDate'].dt.isocalendar().week

# Check the result
print(df[['FlightDate', 'Week']].head())
# Out:
#       FlightDate  Week
# 10000 2019-12-25    52
# 10001 2019-12-30     1
# 10002 2019-04-10    15
# 10003 2019-04-10    15
# 10004 2019-10-18    42

# %%
# Extract year
df['Year'] = df['FlightDate'].dt.year

# Check the result
print(df[['FlightDate', 'Year']].head())
# Out:
#       FlightDate  Year
# 10000 2019-12-25  2019
# 10001 2019-12-30  2019
# 10002 2019-04-10  2019
# 10003 2019-04-10  2019
# 10004 2019-10-18  2019

# %%
print(df[['DayofMonth', 'DayOfWeek']].head())
# print(df[['FlightDate', 'Year']].head())
# Out:
#        DayofMonth  DayOfWeek
# 10000          25          3
# 10001          30          1
# 10002          10          3
# 10003          10          3
# 10004          18          5

# %%
print(df[['Origin', 'Dest']].head())
# Out:
#       Origin Dest
# 10000    BWI  FLL
# 10001    PIA  SFB
# 10002    ATL  BOS
# 10003    LNY  HNL
# 10004    DFW  ORD

# %%
# One-hot encode 'Origin' and 'Dest'
df = pd.get_dummies(df, columns=['Origin', 'Dest'], drop_first=True)

# %%
print(df['DepDelay'].head())
# Out:
# 10000    -1.0
# 10001    11.0
# 10002    -2.0
# 10003    -9.0
# 10004   -11.0
# Name: DepDelay, dtype: float64

# %%
# Example: Assume 'FlightDelay' is the delay in minutes
# Create a binary target: 1 if delay > 15 minutes, else 0
df['Delay'] = (df['DepDelay'] > 15).astype(int)

# %%
# ANALYSIS USING MATPLOTLIB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Count flights by month
flights_by_month = df['Month'].value_counts().sort_index()

# Plot
plt.figure(figsize=(10, 5))
sns.barplot(x=flights_by_month.index, y=flights_by_month.values, palette='viridis')
plt.title('Number of Flights by Month')
plt.xlabel('Month')
plt.ylabel('Number of Flights')
plt.xticks(ticks=range(12), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.show()
# Out:
# <ipython-input-15-85e1d2c48430>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=flights_by_month.index, y=flights_by_month.values, palette='viridis')

# %%
monthly_delay = df.groupby('Month')['DepDelayMinutes'].mean()
print(monthly_delay)
# Out:
# Month
# 1     11.941963
# 2     14.030485
# 3     10.106895
# 4     10.780217
# 5     12.813654
# 6     16.570292
# 7     14.303756
# 8     12.583953
# 9     10.130242
# 10    12.327373
# 11     8.003270
# 12    11.592275
# Name: DepDelayMinutes, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
monthly_delay.plot(kind='line', marker='o', color='teal', title='Average Departure Delay by Month')
plt.xlabel('Month')
plt.ylabel('Average Delay (Minutes)')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(True)
plt.show()

# %%
# Count flights by Year
flights_by_Year = df['Year'].value_counts().sort_index()

# Plot
plt.figure(figsize=(10, 5))
sns.barplot(x=flights_by_Year.index, y=flights_by_Year.values, palette='viridis')
plt.title('Number of Flights by Years')
plt.xlabel('Years')
plt.ylabel('Number of Flights')

plt.show()
# Out:
# <ipython-input-34-451cd1b1d2a1>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=flights_by_Year.index, y=flights_by_Year.values, palette='viridis')

# %%
plt.figure(figsize=(25, 10))
monthly_delays = df.groupby(df['FlightDate'].dt.to_period('M'))['ArrDelayMinutes'].mean()
monthly_delays.plot(kind='line', title='Average Monthly Arrival Delay')
plt.xlabel('Flight Date')
plt.ylabel('Arrival Delay (Minutes)')
plt.show()

# %%
# Count flights by week
flights_by_week = df['Week'].value_counts().sort_index()

# Plot
plt.figure(figsize=(12, 5))
sns.barplot(x=flights_by_week.index, y=flights_by_week.values, palette='magma')
plt.title('Number of Flights by Week of the Year')
plt.xlabel('Week of the Year')
plt.ylabel('Number of Flights')
plt.show()
# Out:
# <ipython-input-16-fba4d6b3d171>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=flights_by_week.index, y=flights_by_week.values, palette='magma')

# %%
# Count flights by week
flights_by_week = df['DayOfWeek'].value_counts().sort_index()

# Plot
plt.figure(figsize=(12, 5))
sns.barplot(x=flights_by_week.index, y=flights_by_week.values, palette='magma')
plt.title('Number of Flights by Day Of Week in total sample')
plt.xlabel('Day of the Week')
plt.ylabel('Number of Flights')
plt.show()
# Out:
# <ipython-input-17-ff4d620ecc01>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=flights_by_week.index, y=flights_by_week.values, palette='magma')

# %%
weekly_delay = df.groupby('DayOfWeek')['ArrDelayMinutes'].mean()
print(weekly_delay)
# Out:
# DayOfWeek
# 1    12.642024
# 2    10.615690
# 3    11.006060
# 4    14.120804
# 5    13.253827
# 6    11.550150
# 7    13.200247
# Name: ArrDelayMinutes, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))
weekly_delay.plot(kind='bar', color='coral', title='Average Arrival Delay by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Average ArrDelay (Minutes)')
plt.xticks(range(7), ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'], rotation=45)
plt.grid(axis='y')
plt.show()

# %%
# Calculate average delay by month
avg_delay_by_month = df.groupby('Month')['ArrDelayMinutes'].mean()

# Plot
plt.figure(figsize=(10, 5))
sns.barplot(x=avg_delay_by_month.index, y=avg_delay_by_month.values, palette='coolwarm')
plt.title('Average Flight ArrDelay by Month')
plt.xlabel('Month')
plt.ylabel('Average Delay Probability')
plt.xticks(ticks=range(12), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.show()
# Out:
# <ipython-input-56-445661758738>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_delay_by_month.index, y=avg_delay_by_month.values, palette='coolwarm')

# %%
# Check the columns in the DataFrame
print(df.columns)
# Out:
# Index(['index', 'FlightDate', 'Airline', 'Cancelled', 'Diverted', 'CRSDepTime',
#        'DepTime', 'DepDelayMinutes', 'DepDelay', 'ArrTime',
#        ...
#        'Dest_VLD', 'Dest_VPS', 'Dest_WRG', 'Dest_WYS', 'Dest_XNA', 'Dest_XWA',
#        'Dest_YAK', 'Dest_YKM', 'Dest_YUM', 'Delay'],
#       dtype='object', length=805)

# %%
# Get the list of all 'Dest' columns
dest_columns = [col for col in df.columns if col.startswith('Dest_')]

# Reconstruct the 'Dest' column
df['Dest'] = df[dest_columns].idxmax(axis=1).str.replace('Dest_', '')

# Check the result
print(df[['Dest']].head())
# Out:
#       Dest
# 10000  FLL
# 10001  SFB
# 10002  BOS
# 10003  HNL
# 10004  ORD

# %%
# Group by 'Dest' and calculate average delay
delay_by_dest = df.groupby('Dest')['ArrDelayMinutes'].mean().sort_values(ascending=False)

# Display top 10 destinations with the highest average delay
print(delay_by_dest.head(10))
# Out:
# Dest
# DIK    449.000000
# VCT    351.500000
# EKO    134.000000
# PLN    128.000000
# DUT    117.000000
# RHI     87.000000
# CYS     86.000000
# GFK     84.454545
# EGE     73.416667
# LBF     71.400000
# Name: ArrDelayMinutes, dtype: float64

# %%
# Before running the groupby, add the 'Origin' column back
# Get the list of all 'Origin' columns
origin_columns = [col for col in df.columns if col.startswith('Origin_')]

# Reconstruct the 'Origin' column
df['Origin'] = df[origin_columns].idxmax(axis=1).str.replace('Origin_', '')

# Now, the groupby should work
delay_by_dest = df.groupby('Origin')['DepDelayMinutes'].mean().sort_values(ascending=False)

# Display top 10 destinations with the highest average delay
print(delay_by_dest.head(10))
# Out:
# Origin
# PQI    256.000000
# RKS    244.666667
# DUT    214.000000
# APN    133.000000
# BFF    107.500000
# ACV    102.285714
# HYA     75.000000
# ALS     66.666667
# RIW     55.000000
# BRO     54.833333
# Name: DepDelayMinutes, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select top 10 destinations with the highest average delay
top_10_dest = delay_by_dest.head(10)

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(x=top_10_dest.values, y=top_10_dest.index, palette='viridis')
plt.title('Top 10 Destinations with Highest Average Flight DepDelay')
plt.xlabel('Average DepDelay Probability')
plt.ylabel('Destination')
plt.show()
# Out:
# <ipython-input-63-5592077ae6f2>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_10_dest.values, y=top_10_dest.index, palette='viridis')

# %%
# Example: Analyze delays for a specific destination (e.g., 'ABC')
specific_dest = 'VCT'
specific_dest_col = f'Dest_{specific_dest}'

# Filter the DataFrame for the specific destination
df_specific_dest = df[df[specific_dest_col] == 1]

# Calculate average delay for this destination
avg_delay = df_specific_dest['Delay'].mean()
print(f'Average delay for {specific_dest}: {avg_delay:.2f}')
# Out:
# Average delay for VCT: 0.50

# %%
# DELAY BY CRSELAPSETIME ()
print(df['CRSElapsedTime'])
# Out:
# 10000    160.0
# 10001    140.0
# 10002    156.0
# 10003     32.0
# 10004    146.0
#          ...
# 59993    103.0
# 59994    114.0
# 59996     48.0
# 59997     62.0
# 59998    107.0
# Name: CRSElapsedTime, Length: 48283, dtype: float64

# %%
# Group by 'Dest' and calculate average delay
delay_by_dest = df.groupby('CRSElapsedTime')['ArrDelayMinutes'].mean().sort_values(ascending=False)

# Display top 10 destinations with the highest average delay
print(delay_by_dest.head(10))
# Out:
# CRSElapsedTime
# 456.0    101.000000
# 408.0     82.000000
# 368.0     58.600000
# 319.0     55.190476
# 504.0     52.000000
# 601.0     52.000000
# 400.0     51.933333
# 323.0     48.857143
# 29.0      45.000000
# 393.0     41.000000
# Name: ArrDelayMinutes, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Scatter plot of CRSElapsedTime vs Delay
plt.figure(figsize=(10, 6))
sns.scatterplot(x='CRSElapsedTime', y='ArrDelayMinutes', data=df, alpha=0.5, color='blue')
plt.title('Relationship Between CRSElapsedTime and Delay')
plt.xlabel('CRSElapsedTime (Minutes)')
plt.ylabel('ArrDelay (Minutes)')
plt.show()

# %%
print(df[['CRSElapsedTime','ArrDelayMinutes']].head())
# Out:
#        CRSElapsedTime  ArrDelayMinutes
# 10000           160.0              0.0
# 10001           140.0              9.0
# 10002           156.0              0.0
# 10003            32.0              0.0
# 10004           146.0              0.0

# %%
# Calculate correlation coefficient
correlation = df['CRSElapsedTime'].corr(df['ArrDelayMinutes'])
print(f'Correlation between CRSElapsedTime and ArrDelay: {correlation:.2f}')
# Out:
# Correlation between CRSElapsedTime and ArrDelay: -0.00

# %%
# Create bins for CRSElapsedTime (e.g., every 30 minutes)
df['CRSElapsedTime_bin'] = pd.cut(df['CRSElapsedTime'], bins=range(0, int(df['CRSElapsedTime'].max()) + 30, 30))

# Check the bins
print(df['CRSElapsedTime_bin'].value_counts().sort_index())
# Out:
# CRSElapsedTime_bin
# (0, 30]          18
# (30, 60]       2222
# (60, 90]      11156
# (90, 120]     10391
# (120, 150]     8036
# (150, 180]     6612
# (180, 210]     3428
# (210, 240]     1976
# (240, 270]     1322
# (270, 300]      942
# (300, 330]      876
# (330, 360]      644
# (360, 390]      413
# (390, 420]      171
# (420, 450]       23
# (450, 480]        5
# (480, 510]       14
# (510, 540]       11
# (540, 570]        4
# (570, 600]       12
# (600, 630]        4
# (630, 660]        0
# (660, 690]        3
# Name: count, dtype: int64

# %%
# Group by CRSElapsedTime_bin and calculate average delay
delay_by_elapsed_time = df.groupby('CRSElapsedTime_bin')['ArrDelayMinutes'].mean()

# Plot the results
plt.figure(figsize=(12, 6))
sns.barplot(x=delay_by_elapsed_time.index.astype(str), y=delay_by_elapsed_time.values, palette='coolwarm')
plt.title('Average ArrDelay by CRSElapsedTime Bins')
plt.xlabel('CRSElapsedTime Bin (Minutes)')
plt.ylabel('Average ArrDelay (Minutes)')
plt.xticks(rotation=90)
plt.show()
# Out:
# <ipython-input-72-f4f056f7077d>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   delay_by_elapsed_time = df.groupby('CRSElapsedTime_bin')['ArrDelayMinutes'].mean()
# <ipython-input-72-f4f056f7077d>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=delay_by_elapsed_time.index.astype(str), y=delay_by_elapsed_time.values, palette='coolwarm')

# %%
#ARRIVAL TIME   AND   DELAY RELATIONSHIP

# %%
def categorize_time(arr_time):
    if 600 <= arr_time < 1200:
        return 'Day (6 AM - 12 PM)'
    elif 1200 <= arr_time < 1800:
        return 'Midday (12 PM - 6 PM)'
    elif 1800 <= arr_time < 2400:
        return 'Night (6 PM - 12 AM)'
    else:
        return 'Midnight (12 AM - 6 AM)'

df['ArrivalTimeBlock'] = df['ArrTime'].apply(categorize_time)

# %%
time_block_delay = df.groupby('ArrivalTimeBlock')['ArrDelayMinutes'].mean()
print(time_block_delay)
# Out:
# ArrivalTimeBlock
# Day (6 AM - 12 PM)          5.992321
# Midday (12 PM - 6 PM)      10.638758
# Midnight (12 AM - 6 AM)    49.191894
# Night (6 PM - 12 AM)       16.222158
# Name: ArrDelayMinutes, dtype: float64

# %%
import matplotlib.pyplot as plt

time_block_delay.plot(kind='bar', color='skyblue', title='Average Arrival Delay by Time Block')
plt.xlabel('Arrival Time Block')
plt.ylabel('Average Delay (Minutes)')
plt.xticks(rotation=45)
plt.show()

# %%
df['Route'] = df['Origin'] + ' → ' + df['Dest']

# %%
route_delay = df.groupby('Route')['ArrDelayMinutes'].mean().reset_index()

# %%
top_50_routes = route_delay.sort_values(by='ArrDelayMinutes', ascending=False).head(50)
print(top_50_routes)
# Out:
#           Route  ArrDelayMinutes
# 4656  SAV → DCA       897.666667
# 1857  EWR → OKC       596.000000
# 1315  DEN → DIK       449.000000
# 1868  EWR → PWM       390.750000
# 106   APN → PLN       384.000000
# 803   CHS → IAD       381.166667
# 4470  RKS → DEN       368.000000
# 2475  IAH → VCT       351.500000
# 414   BGR → ORD       342.000000
# 628   BTV → DEN       338.000000
# 3694  OKC → STL       333.000000
# 1051  COS → PHX       299.000000
# 4318  PQI → EWR       282.500000
# 4438  RDU → PVD       257.000000
# 49    AEX → CLT       248.000000
# 2528  IND → PGD       236.000000
# 1882  EWR → SLC       221.500000
# 3450  MSO → SFO       218.500000
# 1832  EWR → EGE       216.333333
# 1745  DUT → ANC       208.000000
# 4994  SJU → SFB       204.000000
# 5262  SYR → DEN       202.000000
# 2039  FWA → SRQ       197.000000
# 3294  MHT → FLL       195.000000
# 1805  EVV → DTW       191.000000
# 2912  LEX → VPS       189.000000
# 3747  ORD → ASE       177.400000
# 2802  LAX → BDL       173.000000
# 4000  PDX → ONT       173.000000
# 3142  MCO → ORF       172.333333
# 3969  PBI → PVD       163.000000
# 4311  PNS → LGA       161.000000
# 5299  TPA → CVG       160.000000
# 4488  RNO → SAN       155.500000
# 4293  PIT → PIE       154.000000
# 2659  JFK → SMF       153.250000
# 3691  OKC → SFB       152.000000
# 4887  SFO → MSY       152.000000
# 380   BDL → CLT       147.272727
# 642   BUF → DFW       146.500000
# 3703  OMA → EWR       145.000000
# 2645  JFK → PWM       144.500000
# 1598  DFW → STS       144.000000
# 396   BDL → PBI       144.000000
# 4571  SAN → CLE       142.000000
# 455   BLV → VPS       141.500000
# 4937  SHV → IAH       140.250000
# 4924  SGF → SFB       140.000000
# 5022  SLC → FAT       139.333333
# 2015  FNT → PIE       137.750000

# %%
plt.figure(figsize=(15, 8))
plt.barh(top_50_routes['Route'], top_50_routes['ArrDelayMinutes'], color='indianred')
plt.xlabel('Average Arrival Delay (Minutes)')
plt.ylabel('Route')
plt.title('Top 50 Routes with Highest Average Arrival Delay')
plt.gca().invert_yaxis()  # Invert y-axis for better readability
plt.show()

# %%
airline_delay = df.groupby('Airline')['ArrDelayMinutes'].mean().reset_index()

# %%
airline_delay = airline_delay.sort_values(by='ArrDelayMinutes', ascending=False)
print(airline_delay)
# Out:
#                                       Airline  ArrDelayMinutes
# 19                     Peninsula Airways Inc.       162.500000
# 6   Commutair Aka Champlain Enterprises, Inc.        32.173913
# 17                            JetBlue Airways        20.747440
# 12                   ExpressJet Airlines Inc.        18.712329
# 24                      Trans States Airlines        18.673077
# 2                               Allegiant Air        17.929041
# 14   GoJet Airlines, LLC d/b/a United Express        17.285036
# 13                     Frontier Airlines Inc.        16.731282
# 18                         Mesa Airlines Inc.        16.530264
# 23                           Spirit Air Lines        16.473277
# 3                      American Airlines Inc.        13.919738
# 20                          Republic Airlines        13.849822
# 7                            Compass Airlines        13.664706
# 25                      United Air Lines Inc.        12.918614
# 0                 Air Wisconsin Airlines Corp        12.825771
# 5                                 Comair Inc.        12.632047
# 21                      SkyWest Airlines Inc.        12.546144
# 11                                  Envoy Air        10.543950
# 9                        Empire Airlines Inc.        10.400000
# 22                     Southwest Airlines Co.         9.896344
# 10                          Endeavor Air Inc.         9.598876
# 4                 Capital Cargo International         9.208447
# 8                        Delta Air Lines Inc.         9.180842
# 1                        Alaska Airlines Inc.         8.755751
# 16                                Horizon Air         7.172619
# 15                     Hawaiian Airlines Inc.         6.140271

# %%
plt.figure(figsize=(12, 10))
plt.barh(airline_delay['Airline'], airline_delay['ArrDelayMinutes'], color='mediumseagreen')
plt.xlabel('Total Arrival Delay (Minutes)')
plt.ylabel('Airline')
plt.title('Total Arrival Delay by Airline')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.bar(airline_delay['Airline'], airline_delay['ArrDelayMinutes'], color='dodgerblue')
plt.xlabel('Airline')
plt.ylabel('Total Arrival Delay (Minutes)')
plt.title('Total Arrival Delay by Airline')
plt.xticks(rotation=45)
plt.show()
